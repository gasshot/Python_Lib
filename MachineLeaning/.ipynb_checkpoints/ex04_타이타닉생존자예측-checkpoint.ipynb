# %% [markdown]
# ### 학습 목표
#
# - 타이타닉 데이터를 활용해서 생존자 예측 실습을 진행
# - Kaggle 사이트에 결과를 제출하여 높은 점수를 받는게 목표
# - 데이터를 전처리하는 기법에 대해 학습

# %% [markdown]
# # 머신러닝 과정
#
# - 1. 문제를 정의
# - 2. 데이터 수집
# - 3. 데이터 전처리
# - 4. EDA(탐색적 데이터 분석) -> 특성 선택, 특성 삭제
# - 5. 모델 선택및 하이퍼파라미터 조정
# - 6. 모델 예측 및 평가

# %%
# 1. 문제 정의
# -> 타이타닉 생존자를 예측해서 Kaggle에 참여한다.

# 2. 데이터 수집
# -> Kaggle에서 제공

# %%
# 라이브러리 불러오기

# 데이터 공학(전처리)를 위해서 사용
import numpy as np
import pandas as pd

# 데이터 시각화를 위해서 사용
# matplotlib의 단점 : 설정의 자유도가 높지만, 반대로 설정해야하는 내용들이 너무 많다.
# ->  우리는 데이터 시가화를 간단히 하고 싶다. 기본적으로 꾸며져있는 시각화 라이브러리가 필요하다.
# -> 그래서 seaborn이 만들어짐
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 데이터 불러오기

train = pd.read_csv('data/train.csv', index_col='PassengerId')
test = pd.read_csv('data/test.csv', index_col = 'PassengerId')

# %%
# 5개의 데이터를 샘플링

# set_index(), pd.read_csv('파일명' index_col = '원하는 컬럼명')
# train 데이터프레임에서 PassengerId를 인덱스로 설정
# set_index는 바뀐 결과물만 보여주고, 원본 데이터에는 영향 X
# inplace = True -> 원본 데이터에 영향 O
# train = train.set_index('PassengerId', drop=True)

# 상위 5개 행 출력
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
# 타이타닉 데이터 컬럼 설명
# Pclass : 티켓의 등급
# SibSp : 배우자와 형제수
# Parch : 자식과 부모를 합친 수
# Fare : 티켓의 요금
# Embarked : 탑승항
# Survived(정답) : 탑승자가 생존했는지 유무

# %%
# 데이터 확인
# 1. train과 test의 차이점
# 결측치가 존재한다!
# 2. train과 test 각각의 문제점
# train : Age, Cabin, Embarked에 결측치가 존재한다!
# test : Age, Fare, Cabine에 결측치가 존재한다!
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Cabin     91 non-null     object
#  9   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %% [markdown]
# ### 채워줄 결측치의 내용
# - 1. dropna: 결측치가 존재하는 행의 데이터를 삭제
# - 2. 문자데이터 : 일반저긍로 최빈값(가장 많은 값)으로 채워준다.
# - 3. 숫자데이터 : EDA(데이터 시각화)를 통해서, 데이터의 분산을 확인 , 중앙값, 평균으로 채워줄지 결정해야 한다.
# - 4. dropna: 결측치가 존재하는 행의 데이터를 삭제
# - 5. dropna: 결측치가 존재하는 행의 데이터를 삭제

# %%
train['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Embarked를 S로 채워도 무방한지 데이터 시각화를 통해서 확인

import seaborn as sns

# 범주화된 데이터를 시각화 하기 용이한 countplot에
# countplot(data = df자료, x = 기준컬럼명, hue 관측할 컬럼명)
sns.countplot(x="Embarked", hue="Survived", data=train)

# 관측결과 : S, Q에서 탑승한 사람들은 평균적인 생존율을 가지고 이싿.
#           다만 C에서 탑승한 사람들은 조금 더 높은 생존율을 기록하고 있다.
#           -> 모델의 성능이 좋지 않아서, 전처리를 다시 했을 때는 다른 컬럼과 비교하여 데이터를 채워줄 필요가 있다.
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
# 결측치가 2개 뿐이고, S가 압도적으로 많으면서, 생존율에 큰 변화가 없기 때문에
# 결측치를 S라는 문자열로 채워준다.
#

# 하나하나 채워주는 게  아니라, 일괄적으로 같은 값을 입력
train['Embarked'].isnull().sum()
# fillna('채워줄 값')
train['Embarked'].fillna('S', inplace=True)
# Out:
# C:\Users\smhrd\AppData\Local\Temp\ipykernel_4904\2142494439.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Embarked'].fillna('S', inplace=True)

# %%
# 결측치가 채워졌는지 확인

train['Embarked'].isnull().sum()
# Out:
# 0

# %%
test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305          NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308          NaN      0      0              359309    8.0500   NaN        S
# 1309          NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
# test 데이터의 fare(요금)
# 숫자 데이터
# fare와 관련 깊은 특성과 비교해서 전처리

# 기술통계량 확인
test['Fare'].isnull().sum()

# Fare의 분산이 크면서, 데이터의 범위가 넓기 때문에 평균 데이터가 가지는 의미가 많이 퇴색된다.
test.describe()['Fare']
# Out:
# count    417.000000
# mean      35.627188
# std       55.907576
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       31.500000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# 1. pclass와 성별 컬럼을 기준으로 데이터를 확인한다.
# 2. 결측치가 있는 사람의 pclass와 성별을 확인해서 pclass와 성별에 맞는 값을 넣어준다.


# 기준으로 삼고 싶은 데이터가 복수 개라면, 리스트에 묶어서 전달한다.
pt1 = test[['Pclass','Sex','Fare']].groupby(['Pclass','Sex']).median() # 중앙값
pt1
# Pclass가 3이면서 Sex가 남자인 사람의 값을 조회
# loc인데서를 통해서 접근
# 인덱스가 2개 이상 있다면 -> 멀티 인덱스
# 해당 데이터 프레임에 접근 -> 멀티 인덱싱

# loc[행에 대한 접근, 열에 대한 접근]
# loc[('Pclass','Sex'),'Fare'] -> 멀티 인덱스
# Out:
#                    Fare
# Pclass Sex
# 1      female  79.02500
#        male    51.86250
# 2      female  26.00000
#        male    13.00000
# 3      female   8.08125
#        male     7.89580

# %%
aa = []
aa.append((pt1.loc[(1,'male'),'Fare'],'Pclass가 1이면서 Sex가 남자인 Fare(요금)'))
aa.append((pt1.loc[(3,'female'),'Fare'],'Pclass가 3이면서 Sex가 여자인 Fare(요금)'))
aa.append((pt1.loc[(2,'male'),'Fare'],'Pclass가 2이면서 Sex가 남자인 Fare(요금)'))


for a in aa:
    print(a[1], a[0])
# Out:
# Pclass가 1이면서 Sex가 남자인 Fare(요금) 51.8625
# Pclass가 3이면서 Sex가 여자인 Fare(요금) 8.08125
# Pclass가 2이면서 Sex가 남자인 Fare(요금) 13.0

# %%
# isnull함수는 결측치가 잇는 데이터는 True를 반환
# boolean 인덱싱은 True를 만족하는 데이터만 조회
bool1 = test['Fare'].isnull()

# fare가 결측치인 사람의 정보를 조회


test[bool1]['Fare'] = pt1.loc[(3, 'male'), 'Fare']
test[bool1]
# Pclass가 3이면서 Sex가 남자인 Fare(요금)의 중앙값을 채워주자
# 1. fillna를 활용해서 결측치 채워주기
# test['Fare'].fillna('')
# 2. 직접 결측치를 가진 데이터에 접근해서 대입연산자로 넣어주기
# Out:
# C:\Users\smhrd\AppData\Local\Temp\ipykernel_4904\3682113901.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[bool1]['Fare'] = pt1.loc[(3, 'male'), 'Fare']
#              Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# PassengerId
# 1044              3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#              Fare Cabin Embarked
# PassengerId
# 1044          NaN   NaN        S

# %%
test.loc[bool1, 'Fare'] = pt1.loc[(3, 'male'), 'Fare']

test[bool1]
# Out:
#              Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# PassengerId
# 1044              3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#                Fare Cabin Embarked
# PassengerId
# 1044         7.8958   NaN        S

# %%
# train, test의 공통사항
# -> Cabin, Age 결측치 채워주기

# %%
# Age 컬럼 결측치 처리

# 상관관계 파악
# -> 해당 컬럼이 다른 컬럼과 비례하는지, 반비례하는지 확인하는 작업

bool3 = test['Age'].isnull()
test[bool3].count
# Out:
# <bound method DataFrame.count of              Pclass                                               Name  \
# PassengerId
# 902               3                                   Ilieff, Mr. Ylio
# 914               1               Flegenheim, Mrs. Alfred (Antoinette)
# 921               3                                  Samaan, Mr. Elias
# 925               3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 928               3                                Roth, Miss. Sarah A
# ...             ...                                                ...
# 1300              3                    Riordan, Miss. Johanna Hannah""
# 1302              3                             Naughton, Miss. Hannah
# 1305              3                                 Spector, Mr. Woolf
# 1308              3                                Ware, Mr. Frederick
# 1309              3                           Peter, Master. Michael J
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# 902            male  NaN      0      0      349220   7.8958   NaN        S
# 914          female  NaN      0      0    PC 17598  31.6833   NaN        S
# 921            male  NaN      2      0        2662  21.6792   NaN        C
# 925          female  NaN      1      2  W./C. 6607  23.4500   NaN        S
# 928          female  NaN      0      0      342712   8.0500   NaN        S
# ...             ...  ...    ...    ...         ...      ...   ...      ...
# 1300         female  NaN      0      0      334915   7.7208   NaN        Q
# 1302         female  NaN      0      0      365237   7.7500   NaN        Q
# 1305           male  NaN      0      0   A.5. 3236   8.0500   NaN        S
# 1308           male  NaN      0      0      359309   8.0500   NaN        S
# 1309           male  NaN      1      1        2668  22.3583   NaN        C
#
# [86 rows x 10 columns]>

# %%
# Pclass, 성별을 기준으로 Age컬럼 채우기
# 1. 기술 통계량 확인
# -> 데이터의 분산을 확인해서, 중앙값으로 채워줄지 평균값으로 채워줄지 결정

train.describe()['Age']
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
train[['Pclass','Sex','Age']]
# Out:
#              Pclass     Sex   Age
# PassengerId
# 1                 3    male  22.0
# 2                 1  female  38.0
# 3                 3  female  26.0
# 4                 1  female  35.0
# 5                 3    male  35.0
# ...             ...     ...   ...
# 887               2    male  27.0
# 888               1  female  19.0
# 889               3  female   NaN
# 890               1    male  26.0
# 891               3    male  32.0
#
# [891 rows x 3 columns]

# %%
# 2. Age컬럼을 중앙갑으로 채워주긴 할건데, Pclass와 성별을 고려하여 데이터를 채워주기
# Age컬럼을  Pclass와 성별 컬럼을 기준으로 pt2 제작
# -> 그룹화 함수(groupby)를 사용한다.


pt2 = train[['Age', 'Pclass','Sex']].groupby(['Pclass','Sex']).median()

print(pt2)
# Out:
#                 Age
# Pclass Sex
# 1      female  35.0
#        male    40.0
# 2      female  28.0
#        male    30.0
# 3      female  21.5
#        male    25.0

# %%
import numpy as np

def fill_age(train) : # train 데이터를 전달

    # Age가 결측치일 경우에
    if np.isnan(train['Age']) :

        # pt2에서 결측치 데이터의 pclass 값과 성별 값을 가져오기
        
        age_data = pt2.loc[(train['Pclass'],train['Sex']), 'Age'] 
        return age_data
        
    # 결측치가 아닌 경우에
    else :
        return train['Age']

# %%
# train의 Age 컬럼의 결측치 채워주기
# apply함수 활용 결측치를 자동으로 채워주게끔 설계
# apply함수는 사용자가 정의한 함수를 한 행 단위로 작용하게 끔 도와주는 함수
# -> def 사용자 정의 함수
#def aa():
# 해당 데이터가 결측치라면, pclass와 성별을 고려해서 pt2에서 알맞는 값을 꺼내서 넣어주고,
# 결축
    
# bool3 = train['Age'].isnull()
# print(len(train[bool3]))


# df = train[['Age', 'Pclass','Sex']]


# for i in range(len(train)):
#     if np.isnan(train['Age'][i]):  # NaN인지 확인
#         pclass = train.iloc[i, :]['Pclass']
#         sex = train.iloc[i, :]['Sex']
#         age = pt2.loc[(pclass, sex), 'Age']
#         train.loc[i,'Age'] = age 
#         #df.iloc[i, 0]   # 수정된 값을 df에 반영

# # 결과 확인

    

# train['Age'].isnull().sum()

train['Age'] = train.apply(fill_age, axis=1)
test['Age'] = test.apply(fill_age, axis=1)

# %%
# Cabin(객실번호)를 채우기
# 객실번호는 가족이 아니라면 각자 다른 방에 있기 때문에, 각기 다른 방 번호를 가질 수 밖에 없다.
# 최빈값으로 데이터를 채우면, 해당 데이터는 신뢰성이 떨어진다.

# 1. nan값을 Missing(미상)으로 채우고
# -> 'M'이라는 특정 문자로 결측치를 일괄적으로 처리 :fill_na


train['Cabin'].fillna('M',inplace=True)
test['Cabin'].fillna('M',inplace=True)

# 2. 객실번호 데이터에서, 층수 데이터만 뽑아오기
# -> DataFrame 자료를 연산하기 쉬운 형태로 저장하는 것이 목표
# str :DataFrame, Series에서 문자데이터를 일괄적으로 뽑아오는 함수
# -> 인덱싱, 슬라이싱과 같이 사용된다.
train['Deck'] = train['Cabin'].str[0]
test['Deck'] = test['Cabin'].str[0]
# Out:
# C:\Users\smhrd\AppData\Local\Temp\ipykernel_4904\2095812573.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Cabin'].fillna('M',inplace=True)
# C:\Users\smhrd\AppData\Local\Temp\ipykernel_4904\2095812573.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['Cabin'].fillna('M',inplace=True)

# %%
# 필요없는 특성을 제거
# Cabin과 Ticket의 데이터 삭제

train.drop(['Cabin','Ticket'], axis=1, inplace=True)
test.drop(['Cabin','Ticket'], axis=1, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Embarked  891 non-null    object
#  9   Deck      891 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 76.6+ KB

# %% [markdown]
# ### EDA(탐색적 데이터 분석)
#
#     1. Deck(층) 데이터가 Survived(생존)과 연관이 있는지 확인한다.
#     2. Pclass(티켓 등급)데이터가 Survived(생존)과 연관이 얼마나 있는지 확인한다.
#     3. Deck와 Pclass의 시각화를 통해 어느 층이 티켓 등급이 높았는지 확인

# %%
# 1. Deck와 Survived 시각화

train['Deck'].unique()

# 범주화 된(MBTI) 데이터를 시각화할 때 사용하는 그래프
# -> count_plot
# countplot(data = 데이터, x= 기준이 되는 컬럼명, hue = 관측할 컬럼의 이름)
sns.countplot(data = train, x='Deck',hue='Survived' )

# 그래프 출력
plt.show()

# C, E, D , B층에 거준하는 사람들은 비교적 생존율이 높았다.
# T층에 거주하는 사람들은 전부 사망했다.

# %%
# 1. 방번호가 Missing인 사람들은 Pclass가 낮았기 때문에, 승선하는대로 객실을 배정 받았을 확률이 높았을 것이다.

# 2. 위의 이유로 객실번호에 대한 기록이 많이 남지 않았을 것이다.

# 3. Pclass과 Deck간의 관계성을 시각화해보자
# ->  countplot을 활용해서 Deck를 기준으로 Pclass를 관측

sns.countplot(data = train, x='Deck',hue='Pclass' )
# Out:
# <Axes: xlabel='Deck', ylabel='count'>

# %%
# 1. Pclass와 Survived간의 데이터 시각화
sns.countplot(data = train, x='Pclass',hue='Survived' )



plt.show()

# %%
# 2. 성별과 Survived간의 데이터 시각화
sns.countplot(data = train, x='Sex',hue='Survived' )
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# 3. Pclass, 성별을 기준으로 Survived 시각화
# -> 기준이 2개일 경우에 사용하는 그래프 : catplot
# catplot(data = df, x = 첫번째 기준, col = 두번째 기준, hue = 관측할 특성, kind = 그래프의 유형)

sns.catplot(data = train, x = 'Pclass', col = 'Sex', hue = 'Survived', kind='count', palette='pastel')

# 성별이 남자인 경우에는 Pclass가 1등급이더라도, 많이 사망하였다. 2. 3등급 다수가 사망하였다.
# 성별이 여자인 경우에는 Pclass가 1, 2등급이라면, 대부분 생존하였다.

# %% [markdown]
# ### 수치형 데이터를 시각화
#     1. Fare(요금) 데이터를 Survived(생존)과 연관지어서 시각화
#     2. Parch(부모 + 자식)과 SibSp(배우자 + 형제)컬럼을 특성공학한 다음, 결과물을 시각화

# %%
# 수치형 데이터는 countplot으로 시각화가 효과적이지 않다.
# countplot mbti처럼 미리 정의된 몇 가지 클래스를 시각화하는 그래프

# sns.countplot(data = train, x = 'Fare', hue = 'Survived')

# 수치형 데이터는 violinplot이 일반적으로 시각화 효율이 좋다. -> 데이터의 분포를 확인

sns.violinplot(data=train, y = 'Fare', x = 'Sex', hue = 'Survived', split=True)
plt.show()

# Fare가 높을 수록 생존율은 올라간다.

# %%
# Age컬럼과, 성별 컬럼을 기준으로 생존자 유무 데이터 시각화 진행
# Violinplot을 활용해서 성별과 나이를 기준으로 어느 연령대가 많이 죽었는지 확인


sns.violinplot(data=train, y = 'Age', x = 'Sex', hue = 'Survived', split=True, palette='Set2')

# seaborn, matplotlib를 통해서 그린 그래프트를 파일로 저장
# -> plt.savefig(확장자를 포함한 경로, dpi = 화질)
# 주의점 : plt.show() 하기 전의 그래프가 저장되기 때문에 show를 쓰기 전에 작성해야한다.

plt.savefig('성별_나이_생존분석.jpg')

# 남자는 평균적으로 사망자가 더 많지만, 10살 미만의 남자 아이는 대부분 생존했다.
# 여자는 생존가 많은 양상을 보이지만, 10살 미만의 여자 아이는 사망자의 비율이 더 높았다.

# %%
# SibSp, Parch 컬럼이 생존과 관련 있는지 확인
# SibSp : 배우자 + 형제 수
# Parch : 부모 + 자식 수

# train.info()

# violinplot 시각화 하지 않는 이유 : 데이터의 unique값 개수가 많지 않아서
train['Parch'].value_counts


# 1. SibSp 시각화

sns.countplot(data = train, x='SibSp', hue= 'Survived')
plt.show()

# 2. Parch 시각화
sns.countplot(data = train, x='Parch', hue= 'Survived')
plt.show()

# %%
# family(가족) = SibSp + Parch + 1

#
# aa = []
# bb = []

# for i in range(len(train)):
#     temp = train['SibSp'][i] + train['Parch'][i] + 1
#     aa.append(temp)

# for j in range(len(test)):
#     temp = test['SibSp'][j] + test['Parch'][j] + 1
#     bb.append(temp)

# train['Family'] = aa
# test['Family'] = bb

train['Family'] = train['SibSp'] + train['Parch'] + 1
test['Family'] = test['SibSp'] + test['Parch'] + 1

# %%
sns.countplot(data = train, x='Family', hue= 'Survived')
plt.show()

# %%
# Family 데이터를 3그룹으로 그룹핑
# -> 문자데이터를 숫자데이터로 바꿔주는 기법 : 인코딩(map, get_dummies)
# -> 숫자데이터를 문자데이터로 바꿔주는 기법 : 바인딩(cut)

# pd.cut : 데이터를 그룹화(바이닝) 해주기 위해서 사용하는 함수
# ex) 연령데이터(1살~100살) -> 연령대 데이터(청소년, 청년, 장년)

# 1 : Alone, 2 ~ 4 : small_size, 5~ : large_size

# cut 함수의 매개변수
# x = Series 데이터, bins = 데이터를 나룰 구간 ex : [0,1,4,11]
# labels = 구간마다 붙여줄 이름 [Alone, Small, Large]

bins = [0,1,4,11] # 데이터를 나누는 구간
labels = ['Alone', 'Small_size', 'Large_size'] # 구간마다 붙여줄 이름

train_family_size = pd.cut(x=train['Family'],bins = bins,labels =labels)


# family_size train데이터의 Family_size라는 새로운 컬럼으로 추가


train['Family_size'] = train_family_size

train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female  21.5
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch     Fare Embarked Deck  Family Family_size
# PassengerId
# 1                1      0   7.2500        S    M       2  Small_size
# 2                1      0  71.2833        C    C       2  Small_size
# 3                0      0   7.9250        S    M       1       Alone
# 4                1      0  53.1000        S    C       2  Small_size
# 5                0      0   8.0500        S    M       1       Alone
# ...            ...    ...      ...      ...  ...     ...         ...
# 887              0      0  13.0000        S    M       1       Alone
# 888              0      0  30.0000        S    B       1       Alone
# 889              1      2  23.4500        S    M       4  Small_size
# 890              0      0  30.0000        C    C       1       Alone
# 891              0      0   7.7500        Q    M       1       Alone
#
# [891 rows x 12 columns]

# %%
# test 데이터에도 Family_size 컬럼을 추가

bins = [0,1,4,11] # 데이터를 나누는 구간
labels = ['Alone', 'Small_size', 'Large_size'] # 구간마다 붙여줄 이름

test_family_size = pd.cut(x=test['Family'],bins = bins,labels =labels)

test['Family_size'] = test_family_size

# %%
test.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch     Fare Embarked Deck  Family Family_size
# PassengerId
# 892          34.5      0      0   7.8292        Q    M       1       Alone
# 893          47.0      1      0   7.0000        S    M       2  Small_size
# 894          62.0      0      0   9.6875        Q    M       1       Alone
# 895          27.0      0      0   8.6625        S    M       1       Alone
# 896          22.0      1      1  12.2875        S    M       3  Small_size

# %%
# Name 컬럼의 중간에는 호칭에 대한 데이터가 들어있고, 해당 데이터는 생존에 유의미한 정보를 포함할 것이다.

# 데이터 프레임에서 문자데이터를 일괄적으로 다루기 위해 str함수를 먼저 사용한다.
# 문자 데이터를 특정 기준으로 나눠주는 함수
# split() : 문자 데이터를 특정 기준으로 나눠주는 함수

train['Title'] = train['Name'].str.split(', ').str[1].str.split('.').str[0]
test['Title'] = test['Name'].str.split(', ').str[1].str.split('.').str[0]

# %%
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female  21.5
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch     Fare Embarked Deck  Family Family_size Title
# PassengerId
# 1                1      0   7.2500        S    M       2  Small_size    Mr
# 2                1      0  71.2833        C    C       2  Small_size   Mrs
# 3                0      0   7.9250        S    M       1       Alone  Miss
# 4                1      0  53.1000        S    C       2  Small_size   Mrs
# 5                0      0   8.0500        S    M       1       Alone    Mr
# ...            ...    ...      ...      ...  ...     ...         ...   ...
# 887              0      0  13.0000        S    M       1       Alone   Rev
# 888              0      0  30.0000        S    B       1       Alone  Miss
# 889              1      2  23.4500        S    M       4  Small_size  Miss
# 890              0      0  30.0000        C    C       1       Alone    Mr
# 891              0      0   7.7500        Q    M       1       Alone    Mr
#
# [891 rows x 13 columns]

# %%
# Title이라는 사람에 대한 사회적 지위 정보를 담은 컬럼을 생성
# 해당 컬럼이 생존과 관련이 있는지 countplot으로 확인하자
print(train['Title'].unique())

# 의미를 가지고 있는 호칭이 몇 개 되지 않는다.
# 'Mr' 'Mrs' 'Miss' 'Master' 'Rev'만 가져가고, 나머지는  Other(기타)값으로 변환

plt.figure(figsize=(15,5))
sns.countplot(data = train, x= 'Title', hue='Survived')
plt.show()
# Out:
# ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Mme' 'Ms' 'Major' 'Lady'
#  'Sir' 'Mlle' 'Col' 'Capt' 'the Countess' 'Jonkheer']

# %%
# 기존에 갖고 있던 특정값을 일괄적으로 변환
# labelEncoding때 사용했던 map함수를 통해 일괄적으로 데이터를 원하는 값으로 바꿔줄 수 있다.
# zip 함수로 편하게 딕셔너리를 생성

list1 = ['고민성', '채수민', '임다이', '김민수', '고선아']
list2 = ['남자', '여자', '여자', '남자', '여자']

dict(zip(list1,list2))

# map 함수에서 사용할 딕셔너리를 정의

title = train['Title'].unique() # key값에 들어갈 배열

# 'Mr', 'Mrs', 'Miss', 'Master', 'Rev'만 가져가고, 나머지는 'Other'는 값으로 치환

convert_list = ['Mr', 'Mrs', 'Miss', 'Master', 'Other', 'Rev'] +(['Other'] * 11)
# zip 함수를 통해 title과 convert_list를 dict로 반환


map1 = dict(zip(title,convert_list))

map1
# Out:
# {'Mr': 'Mr',
#  'Mrs': 'Mrs',
#  'Miss': 'Miss',
#  'Master': 'Master',
#  'Don': 'Other',
#  'Rev': 'Rev',
#  'Dr': 'Other',
#  'Mme': 'Other',
#  'Ms': 'Other',
#  'Major': 'Other',
#  'Lady': 'Other',
#  'Sir': 'Other',
#  'Mlle': 'Other',
#  'Col': 'Other',
#  'Capt': 'Other',
#  'the Countess': 'Other',
#  'Jonkheer': 'Other'}

# %%
# map 함수를 활용해서 title 내부의 값을 변환

train['Title'] = train['Title'].map(map1)
test['Title'] = test['Title'].map(map1)
test['Title'] = test['Title'].fillna('Other')

# %%
# 데이터 확인
# 필요없는 데이터 삭제
# Name, SibSp, Parch, Family를 train과 test에서 삭제


# train.drop(train.loc[:,['Name','SibSp', 'Parch', 'Family']])
# test.drop(test.loc[:,['Name','SibSp', 'Parch', 'Family']])

train.loc[:,['Name','SibSp', 'Parch', 'Family']]

# train.info()
# test.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 9
#       1 # 데이터 확인
#       2 # 필요없는 데이터 삭제
#       3 # Name, SibSp, Parch, Family를 train과 test에서 삭제
#    (...)
#       6 # train.drop(train.loc[:,['Name','SibSp', 'Parch', 'Family']])
#       7 # test.drop(test.loc[:,['Name','SibSp', 'Parch', 'Family']])
# ----> 9 drop(train.loc[:,['Name','SibSp', 'Parch', 'Family']])
#
# NameError: name 'drop' is not defined

# %%
# 기존에 갖고 있던 특정값을 일괄적으로 변환
# labelEncoding때 사용했던 map함수를 통해 일괄적으로 데이터를 원하는 값으로 바꿔줄 수 있다.
# zip 함수로 편하게 딕셔너리를 생성


# aa = train['Title'].unique()
# bb = []

# for i in range(len(aa)):
#     if(aa[i] == 'Mr'):
#         bb.append('Mr')
#         continue
#     elif(aa[i] == 'Mrs'):
#         bb.append('Mrs')
#         continue
#     elif(aa[i] == 'Miss'):
#         bb.append('Miss')
#         continue
#     elif(aa[i] == 'Master'):
#         bb.append('Master')
#         continue
#     elif(aa[i] == 'Rev'):
#         bb.append('Rev')
#         continue
#     bb.append('Other')


# #print(bb)

# cc = dict(zip(aa,bb))
    
# for i in range(1,len(train['Title'])+1):
#     #print(train['Title'][i])
#     train['Title'][i] = cc[train['Title'][i]]


# plt.figure(figsize=(15,5))
# sns.countplot(data = train, x= 'Title', hue='Survived')
# plt.show()
